# %% [markdown]
# # Assignment 3 : Multi-label Image Classification

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
import os
os.chdir("/content/gdrive/My Drive/Assignment3_p1")

# %%
ls
# Out:
# classifier.py      kaggle_submission.py  __pycache__/        VOCdevkit_2007/
# download_data.sh   MP3_P1.ipynb          voc_classifier.pth
# instruction.ipynb  my_solution.csv       voc_dataloader.py

# %%
# %%bash
# #wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# #tar -xf VOCtrainval_06-Nov-2007.tar
# #mv VOCdevkit VOCdevkit_2007
# #rm VOCtrainval_06-Nov-2007.tar
#
# #wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# #tar -xf VOCtest_06-Nov-2007.tar
# #mv VOCdevkit/VOC2007 VOCdevkit_2007/VOC2007test
# #rmdir VOCdevkit
# #rm VOCtest_06-Nov-2007.tar

# %% [markdown]
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.

# %%
# !pip3 install torch torchvision
# !pip3 install opencv-contrib-python==4.0.0.21
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.0.1.post2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.2.post3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.16.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (4.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.12.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision) (0.46)
# Requirement already satisfied: opencv-contrib-python==4.0.0.21 in /usr/local/lib/python3.6/dist-packages (4.0.0.21)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-contrib-python==4.0.0.21) (1.16.3)

# %%
import torch
a = torch.Tensor([1]).cuda()
print(a)
# Out:
# tensor([1.], device='cuda:0')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import cv2
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import Classifier
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    print(img.size)
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))
# Out:
# (500, 375)
# (500, 331)
# (318, 480)
# (500, 375)
# (500, 375)

# %% [markdown]
# # Classification

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss)
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = torch.mean(torch.stack(losses))
        #test_loss = np.mean(losses)
        print('mAP: {0:.4f}'.format(mAP))
        print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %% [markdown]
# ## Modifying the network
#
# The network you are given as is will allow you to reach around 0.15-0.2 mAP. To meet the benchmark for this assignment you will need to improve the network. There are a variety of different approaches you should try:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function

# %%
classifier = Classifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.02, momentum=0.9)

# %%
# Training the Classifier
NUM_EPOCHS = 25
TEST_FREQUENCY = 5

for epoch in range(1, NUM_EPOCHS+1):
    print("Starting epoch number " + str(epoch))
    train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
    print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
    if(epoch%TEST_FREQUENCY==0):
        mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
        print('Evaluating classifier')
        print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.23904424905776978
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.24155378341674805
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23854802548885345
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.23769304156303406
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23757770657539368
# -------  Class: aeroplane        AP:   0.0945  -------
# -------  Class: bicycle          AP:   0.0455  -------
# -------  Class: bird             AP:   0.1022  -------
# -------  Class: boat             AP:   0.0684  -------
# -------  Class: bottle           AP:   0.0408  -------
# -------  Class: bus              AP:   0.0287  -------
# -------  Class: car              AP:   0.1121  -------
# -------  Class: cat              AP:   0.1061  -------
# -------  Class: chair            AP:   0.1330  -------
# -------  Class: cow              AP:   0.0359  -------
# -------  Class: diningtable      AP:   0.0600  -------
# -------  Class: dog              AP:   0.1122  -------
# -------  Class: horse            AP:   0.0570  -------
# -------  Class: motorbike        AP:   0.0400  -------
# -------  Class: person           AP:   0.4687  -------
# -------  Class: pottedplant      AP:   0.0515  -------
# -------  Class: sheep            AP:   0.0535  -------
# -------  Class: sofa             AP:   0.1211  -------
# -------  Class: train            AP:   0.0435  -------
# -------  Class: tvmonitor        AP:   0.0526  -------
# mAP: 0.0914
# Avg loss: 0.2349187135696411
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.09135225718842759
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23858222365379333
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23592762649059296
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23480860888957977
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23685811460018158
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.23314422369003296
# -------  Class: aeroplane        AP:   0.2467  -------
# -------  Class: bicycle          AP:   0.0595  -------
# -------  Class: bird             AP:   0.1177  -------
# -------  Class: boat             AP:   0.1576  -------
# -------  Class: bottle           AP:   0.0453  -------
# -------  Class: bus              AP:   0.0412  -------
# -------  Class: car              AP:   0.1509  -------
# -------  Class: cat              AP:   0.0825  -------
# -------  Class: chair            AP:   0.1566  -------
# -------  Class: cow              AP:   0.0379  -------
# -------  Class: diningtable      AP:   0.0747  -------
# -------  Class: dog              AP:   0.0952  -------
# -------  Class: horse            AP:   0.0663  -------
# -------  Class: motorbike        AP:   0.0482  -------
# -------  Class: person           AP:   0.4806  -------
# -------  Class: pottedplant      AP:   0.0682  -------
# -------  Class: sheep            AP:   0.0373  -------
# -------  Class: sofa             AP:   0.1177  -------
# -------  Class: train            AP:   0.0947  -------
# -------  Class: tvmonitor        AP:   0.0513  -------
# mAP: 0.1115
# Avg loss: 0.22976946830749512
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.11149487772338913
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23125982284545898
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.229853093624115
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23212890326976776
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22865138947963715
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.22527183592319489
# -------  Class: aeroplane        AP:   0.2971  -------
# -------  Class: bicycle          AP:   0.0701  -------
# -------  Class: bird             AP:   0.1010  -------
# -------  Class: boat             AP:   0.2194  -------
# -------  Class: bottle           AP:   0.0743  -------
# -------  Class: bus              AP:   0.0713  -------
# -------  Class: car              AP:   0.2029  -------
# -------  Class: cat              AP:   0.1144  -------
# -------  Class: chair            AP:   0.2031  -------
# -------  Class: cow              AP:   0.0375  -------
# -------  Class: diningtable      AP:   0.1341  -------
# -------  Class: dog              AP:   0.1153  -------
# -------  Class: horse            AP:   0.0796  -------
# -------  Class: motorbike        AP:   0.0558  -------
# -------  Class: person           AP:   0.5009  -------
# -------  Class: pottedplant      AP:   0.0780  -------
# -------  Class: sheep            AP:   0.0314  -------
# -------  Class: sofa             AP:   0.1456  -------
# -------  Class: train            AP:   0.1598  -------
# -------  Class: tvmonitor        AP:   0.0596  -------
# mAP: 0.1376
# Avg loss: 0.22245295345783234
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.13755493578950584
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22582654654979706
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22484001517295837
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2212434560060501
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.22675585746765137
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.23495309054851532
# -------  Class: aeroplane        AP:   0.3499  -------
# -------  Class: bicycle          AP:   0.0699  -------
# -------  Class: bird             AP:   0.0894  -------
# -------  Class: boat             AP:   0.2118  -------
# -------  Class: bottle           AP:   0.0623  -------
# -------  Class: bus              AP:   0.0761  -------
# -------  Class: car              AP:   0.2364  -------
# -------  Class: cat              AP:   0.1515  -------
# -------  Class: chair            AP:   0.1698  -------
# -------  Class: cow              AP:   0.0399  -------
# -------  Class: diningtable      AP:   0.1120  -------
# -------  Class: dog              AP:   0.1385  -------
# -------  Class: horse            AP:   0.0947  -------
# -------  Class: motorbike        AP:   0.0567  -------
# -------  Class: person           AP:   0.5226  -------
# -------  Class: pottedplant      AP:   0.0729  -------
# -------  Class: sheep            AP:   0.0311  -------
# -------  Class: sofa             AP:   0.1391  -------
# -------  Class: train            AP:   0.2118  -------
# -------  Class: tvmonitor        AP:   0.0712  -------
# mAP: 0.1454
# Avg loss: 0.22150228917598724
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.1453787889960993
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.2220737636089325
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.21840150654315948
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.2170872688293457
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.2194182574748993
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.21769654750823975
# -------  Class: aeroplane        AP:   0.3636  -------
# -------  Class: bicycle          AP:   0.1405  -------
# -------  Class: bird             AP:   0.1148  -------
# -------  Class: boat             AP:   0.2216  -------
# -------  Class: bottle           AP:   0.0757  -------
# -------  Class: bus              AP:   0.1031  -------
# -------  Class: car              AP:   0.3058  -------
# -------  Class: cat              AP:   0.1801  -------
# -------  Class: chair            AP:   0.2271  -------
# -------  Class: cow              AP:   0.0384  -------
# -------  Class: diningtable      AP:   0.1627  -------
# -------  Class: dog              AP:   0.1557  -------
# -------  Class: horse            AP:   0.1254  -------
# -------  Class: motorbike        AP:   0.1365  -------
# -------  Class: person           AP:   0.5479  -------
# -------  Class: pottedplant      AP:   0.1008  -------
# -------  Class: sheep            AP:   0.0293  -------
# -------  Class: sofa             AP:   0.1537  -------
# -------  Class: train            AP:   0.2304  -------
# -------  Class: tvmonitor        AP:   0.1002  -------
# mAP: 0.1757
# Avg loss: 0.215115025639534
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.1756687490616316

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# -------  Class: aeroplane        AP:   0.3564  -------
# -------  Class: bicycle          AP:   0.1097  -------
# -------  Class: bird             AP:   0.1189  -------
# -------  Class: boat             AP:   0.1753  -------
# -------  Class: bottle           AP:   0.0777  -------
# -------  Class: bus              AP:   0.0844  -------
# -------  Class: car              AP:   0.3514  -------
# -------  Class: cat              AP:   0.1527  -------
# -------  Class: chair            AP:   0.2253  -------
# -------  Class: cow              AP:   0.0383  -------
# -------  Class: diningtable      AP:   0.1617  -------
# -------  Class: dog              AP:   0.1602  -------
# -------  Class: horse            AP:   0.1528  -------
# -------  Class: motorbike        AP:   0.1147  -------
# -------  Class: person           AP:   0.5614  -------
# -------  Class: pottedplant      AP:   0.0820  -------
# -------  Class: sheep            AP:   0.0359  -------
# -------  Class: sofa             AP:   0.1505  -------
# -------  Class: train            AP:   0.2294  -------
# -------  Class: tvmonitor        AP:   0.0999  -------
# mAP: 0.1719
# Avg loss: 0.21120044589042664

# %%
output_submission_csv('my_solution.csv', test_aps)
